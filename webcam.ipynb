# %%
from ultralytics import YOLO
# from ultralytics.yolo.v8.detect.predict import DetectionPredictor
import cv2

model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="coco128.yaml", epochs=3)  # train the model
metrics = model.val()  # evaluate model performance on the validation set

# %% [markdown]
# __use webcam for object detection input stream__

# %%
results = model.predict(source="0",show = True)

# %% [markdown]
# __object detection in image__

# %%
results = model("bus.jpg")  # replace "bus.jpg" with path to img
results
# Out:
# image 1/1 /home/zeal/Downloads/programming/computer_vision/yolo/on coco/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 4.9ms
# Speed: 10.1ms preprocess, 4.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %% [markdown]
# __run the model for object detection in video__

# %%
result_on_video = model("vdo_2.mp4")
# replace "vdo_2.mp4" with path to vdo
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/2992) /home/zeal/Downloads/programming/computer_vision/yolo/on coco/vdo_2.mp4: 320x640 3 persons, 1 microwave, 79.4ms
# video 1/1 (frame 2/2992) /home/zeal/Downloads/programming/computer_vision/yolo/on coco/vdo_2.mp4: 320x640 3 persons, 1 microwave, 3.6ms
# video 1/1 (frame 3/2992) /home/zeal/Downloads/programming/computer_vision/yolo/on coco/vdo_2.mp4: 320x640 3 persons, 1 microwave, 3.6ms
# ...
